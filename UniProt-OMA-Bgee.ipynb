# %% [markdown]
# ## This notebook accompanies our submission for SWAT4HCLS 2023 "data-in-use", showcasing federated queries across UniProt, OMA and Bgee for identifying essential proteins
#
# #### Note: we build the query progressively to illustrate step by step how to achieve the end result. We also highlight lessons learned for each of the steps, where relevant.

# %%
# helper functions
import sys
# !{sys.executable} -m pip install SPARQLWrapper
from SPARQLWrapper import SPARQLWrapper, JSON
import sys, os, time
import pandas as pd

# always display full column results (don't truncate output)
pd.set_option('display.max_colwidth', -1)

OMA_SPARQL_endpoint = "https://sparql.omabrowser.org/sparql"
Bgee_SPARQL_endpoint = "https://bgee.org/sparql/"
UniProt_SPARQL_endpoint = "https://sparql.uniprot.org/sparql/"

# the endpoints must be defined as wrappers for executing SPARQL queries
sparql_endpoint_OMA = SPARQLWrapper(OMA_SPARQL_endpoint)
sparql_endpoint_UniProt = SPARQLWrapper(UniProt_SPARQL_endpoint)

# function to print in a table results of a SPARQL query
def pretty_print(results):
    
    # how to transform SPARQL results into Pandas dataframes
    
    # get header (column names) from results
    header = results["results"]["bindings"][0].keys()

    # display table of results:
    table = []
    
    # the SPARQL JSON results to the query are available in the "results", "bindings" entry:
    for entry in results["results"]["bindings"]:
        # append entries from the results to a regular Python list of rows, which we can then transform to a Pandas DF
        row = [entry[column]["value"] if entry.get(column, None) != None else None for column in header]
        table.append(row)
    df = pd.DataFrame(table, columns=list(header))
    return df
# Out:
# Requirement already satisfied: SPARQLWrapper in /Users/asima/opt/anaconda3/lib/python3.9/site-packages (1.8.5)
# Requirement already satisfied: rdflib>=4.0 in /Users/asima/opt/anaconda3/lib/python3.9/site-packages (from SPARQLWrapper) (6.2.0)
# Requirement already satisfied: isodate in /Users/asima/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=4.0->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: setuptools in /Users/asima/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=4.0->SPARQLWrapper) (58.0.4)
# Requirement already satisfied: pyparsing in /Users/asima/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=4.0->SPARQLWrapper) (3.0.4)
# Requirement already satisfied: six in /Users/asima/opt/anaconda3/lib/python3.9/site-packages (from isodate->rdflib>=4.0->SPARQLWrapper) (1.16.0)
# /var/folders/5d/3j6fyxq90gs2qdxgzpzsl1gh0000gp/T/ipykernel_54782/2522515982.py:9: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### 1. Identify the taxon ID of "S. cerevisiae" in OMA RDF

# %% [markdown]
# #### First attempt: fetch directly from OMA

# %%
query_OMA_s_cerevisiae = """
PREFIX oma: <http://omabrowser.org/ontology/oma#>
PREFIX orth: <http://purl.org/net/orth#>
PREFIX sio: <http://semanticscience.org/resource/>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX obo: <http://purl.obolibrary.org/obo/>

select ?taxon ?name where {
    # ?taxon  a up:Taxon.
    # ?taxon up:scientificName ?name.
    filter (strstarts (lcase(?name), "saccharomyces cerevisiae" ))
}
"""

# %%
# set the query to be executed against the OMA endpoint and set the return format to JSON
sparql_endpoint_OMA.setQuery(query_OMA_s_cerevisiae)
sparql_endpoint_OMA.setReturnFormat(JSON)

results = sparql_endpoint_OMA.query().convert()

pretty_print(results)
# Out:
#                                      taxon  \
# 0  http://purl.uniprot.org/taxonomy/559292
# 1  http://purl.uniprot.org/taxonomy/764097
# 2  http://purl.uniprot.org/taxonomy/764099
# 3  http://purl.uniprot.org/taxonomy/764101
#
#                                                     name
# 0  Saccharomyces cerevisiae (strain ATCC 204508 / S288c)
# 1  Saccharomyces cerevisiae (strain AWRI796)
# 2  Saccharomyces cerevisiae (strain VIN 13)
# 3  Saccharomyces cerevisiae (strain FostersO)

# %% [markdown]
#  Since there are multiple such taxa, we need to decide which one is the reference we should use in going forward. For this, since the OMA RDF does not store GO annotations, we will federate with UniProt to compute the number of annotations per taxon. We will consider the reference one to be the highest annotated one.

# %% [markdown]
# ### 2. Combine with UniProt to identify taxon with most GO term annotations (this will be the reference one)
# Note: despite how few taxa are transmitted from OMA to UniProt, this query takes very long to execute. This is  because all annotations need to be fetched from uniprot and sent back over before computing the aggregation.

# %%
# %%time
query_OMA_UniProt_s_cerevisiae = """
PREFIX oma: <http://omabrowser.org/ontology/oma#>
PREFIX orth: <http://purl.org/net/orth#>
PREFIX sio: <http://semanticscience.org/resource/>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX obo: <http://purl.obolibrary.org/obo/>

select ?taxon (count (distinct ?goTerm) as ?num_annot) where {
    # ?taxon  a up:Taxon.
    # ?taxon up:scientificName ?name.
    filter (strstarts (lcase(?name), "saccharomyces cerevisiae" ))
    SERVICE <http://sparql.uniprot.org/sparql> {
        Select ?taxon ?goTerm where {
            # ?protein a up:Protein .
            # ?protein up:classifiedWith ?goTerm .
            # ?protein  up:organism ?taxon .
        } 
    }
} group by ?taxon order by desc(?num_annot) # limit 1 -- if we only want to directly fetch the top one

"""

sparql_endpoint_OMA.setQuery(query_OMA_UniProt_s_cerevisiae)
sparql_endpoint_OMA.setReturnFormat(JSON)

results = sparql_endpoint_OMA.query().convert()

pretty_print(results)
# Out:
# CPU times: user 56.6 ms, sys: 14.9 ms, total: 71.5 ms
# Wall time: 5min 37s
#                                      taxon num_annot
# 0  http://purl.uniprot.org/taxonomy/559292  6417
# 1  http://purl.uniprot.org/taxonomy/764097  81
# 2  http://purl.uniprot.org/taxonomy/764099  70
# 3  http://purl.uniprot.org/taxonomy/764101  60

# %% [markdown]
# ### 2b. Execute same query at UniProt site (invoking OMA remotely)

# %%
# %%time
query_UniProt_OMA = """
PREFIX oma: <http://omabrowser.org/ontology/oma#>
PREFIX orth: <http://purl.org/net/orth#>
PREFIX sio: <http://semanticscience.org/resource/>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX obo: <http://purl.obolibrary.org/obo/>

SELECT ?taxon (count (distinct ?goTerm) as ?num_annot) where {
  SERVICE<https://sparql.omabrowser.org/sparql>{
select ?taxon where {
# ?taxon  a up:Taxon.
# ?taxon up:scientificName ?name.
filter (strstarts (lcase(?name), "saccharomyces cerevisiae" ))
    } }
# ?protein a up:Protein .
    	# ?protein up:classifiedWith ?goTerm .
    	# ?protein  up:organism ?taxon . 
  
} group by ?taxon order by desc(?num_annot) # limit 1 -- if we only want to directly fetch the top one


"""

sparql_endpoint_UniProt.setQuery(query_UniProt_OMA)
sparql_endpoint_UniProt.setReturnFormat(JSON)

results = sparql_endpoint_UniProt.query().convert()

pretty_print(results)
# Out:
# CPU times: user 17.4 ms, sys: 5.18 ms, total: 22.6 ms
# Wall time: 1.28 s
#   num_annot                                    taxon
# 0  6417      http://purl.uniprot.org/taxonomy/559292
# 1  81        http://purl.uniprot.org/taxonomy/764097
# 2  70        http://purl.uniprot.org/taxonomy/764099
# 3  60        http://purl.uniprot.org/taxonomy/764101

# %% [markdown]
# The previous query illustrates that the taxon we are looking for is certainly NCBI ID 559292. We will use this throughout the remainder of the tutorial directly.
#
# ###### **LESSON LEARNED no. 1: generating and transfering large intermediate results can make order of magnitude difference in performance. However, it is not always easy to predict which query fragments will lead to this problem.**

# %% [markdown]
# ### 3. Compute orthologs of S. cerevisiae in reference species.
#
# Here, as an optimisation we could restrict reference species to be those available in Bgee, as those are the only ones for which we can further compute expression profiles

# %%
query_Bgee_OMA = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dct: <http://purl.org/dc/terms/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX ensembl: <http://rdf.ebi.ac.uk/resource/ensembl/>
PREFIX oma: <http://omabrowser.org/ontology/oma#>
PREFIX orth: <http://purl.org/net/orth#>
PREFIX sio: <http://semanticscience.org/resource/>
PREFIX taxon: <http://purl.uniprot.org/taxonomy/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX void: <http://rdfs.org/ns/void#>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX genex: <http://purl.org/genex#>

select ?p ?species ?orthologGeneEns ?anat  where {
# ?p a orth:Protein.
# ?p orth:organism/obo:RO_0002162 taxon:559292.
# ?cluster a orth:OrthologsCluster.
# ?cluster orth:hasHomologousMember ?node1.
# ?cluster orth:hasHomologousMember ?node2. 
# ?node2 orth:hasHomologousMember* ?ortholog. 
# ?node1 orth:hasHomologousMember* ?p.
# ?ortholog sio:SIO_010079 ?gene . #is encoded by
# ?gene lscr:xrefEnsemblGene ?orthologGeneEns .
# ?ortholog orth:organism/obo:RO_0002162/up:scientificName ?species.
  
filter(?node1 != ?node2) 
}

"""

# %% [markdown]
# ### 4. Having computed orthologs, now also compute where these are highly expressed (federated query OMA + BGEE)

# %%
# %%time
query_Bgee_OMA = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dct: <http://purl.org/dc/terms/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX ensembl: <http://rdf.ebi.ac.uk/resource/ensembl/>
PREFIX oma: <http://omabrowser.org/ontology/oma#>
PREFIX orth: <http://purl.org/net/orth#>
PREFIX sio: <http://semanticscience.org/resource/>
PREFIX taxon: <http://purl.uniprot.org/taxonomy/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX void: <http://rdfs.org/ns/void#>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX genex: <http://purl.org/genex#>

select ?p ?species ?orthologGeneEns ?anat  where {
# ?p a orth:Protein.
# ?p orth:organism/obo:RO_0002162 taxon:559292.
# ?cluster a orth:OrthologsCluster.
# ?cluster orth:hasHomologousMember ?node1.
# ?cluster orth:hasHomologousMember ?node2. 
# ?node2 orth:hasHomologousMember* ?ortholog. 
# ?node1 orth:hasHomologousMember* ?p.
# ?ortholog sio:SIO_010079 ?gene . #is encoded by
# ?gene lscr:xrefEnsemblGene ?orthologGeneEns .
# ?ortholog orth:organism/obo:RO_0002162/up:scientificName ?species.
  
filter(?node1 != ?node2) 
  
  SERVICE <https://bgee.org/sparql/> {
			SELECT DISTINCT ?orthologGeneEns ?anat {
				# ?geneB a orth:Gene .
				# ?geneB lscr:xrefEnsemblGene ?orthologGeneEns .
                # ?expr <http://purl.org/genex#hasSequenceUnit> ?geneB.
                # ?expr a <http://purl.org/genex#Expression> .
                # ?expr genex:hasConfidenceLevel obo:CIO_0000029 . # high confidence level
                # ?expr genex:hasExpressionLevel ?exprLevel .
                FILTER (?exprLevel > 99) # highly expressed
                # ?cond genex:hasAnatomicalEntity ?anat .
			}
  }
 
}

"""

sparql_endpoint_OMA.setQuery(query_Bgee_OMA)
sparql_endpoint_OMA.setReturnFormat(JSON)

results = sparql_endpoint_OMA.query().convert()

pretty_print(results)
# Out:
# CPU times: user 8.2 s, sys: 5.62 s, total: 13.8 s
# Wall time: 43min 34s
#                                                   p          species  \
# 0        https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 1        https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 2        https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 3        https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 4        https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# ...                                             ...              ...
# 1048571  https://omabrowser.org/oma/info/YEAST03625  Mus musculus
# 1048572  https://omabrowser.org/oma/info/YEAST03625  Mus musculus
# 1048573  https://omabrowser.org/oma/info/YEAST03625  Mus musculus
# 1048574  https://omabrowser.org/oma/info/YEAST03625  Mus musculus
# 1048575  https://omabrowser.org/oma/info/YEAST03625  Mus musculus
#
#                                                   orthologGeneEns  \
# 0        http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 1        http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 2        http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 3        http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 4        http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# ...                                                           ...
# 1048571  http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000024598
# 1048572  http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000024598
# 1048573  http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000024598
# 1048574  http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000024598
# 1048575  http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000024598
#
#                                                   anat
# 0        http://purl.obolibrary.org/obo/UBERON_0001152
# 1        http://purl.obolibrary.org/obo/UBERON_0001174
# 2        http://purl.obolibrary.org/obo/UBERON_0002205
# 3        http://purl.obolibrary.org/obo/UBERON_0002395
# 4        http://purl.obolibrary.org/obo/UBERON_0003700
# ...                                                ...
# 1048571  http://purl.obolibrary.org/obo/CL_0000842
# 1048572  http://purl.obolibrary.org/obo/UBERON_0000051
# 1048573  http://purl.obolibrary.org/obo/UBERON_0000569
# 1048574  http://purl.obolibrary.org/obo/UBERON_0001371
# 1048575  http://purl.obolibrary.org/obo/UBERON_0001374
#
# [1048576 rows x 4 columns]

# %% [markdown]
# ### 4b. Optimisation: restrict orthologs to those in species available in Bgee, re-run query and compare timing

# %%
# %%time
query_Bgee_OMA = """
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
PREFIX dc: <http://purl.org/dc/elements/1.1/>
PREFIX dct: <http://purl.org/dc/terms/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX ensembl: <http://rdf.ebi.ac.uk/resource/ensembl/>
PREFIX oma: <http://omabrowser.org/ontology/oma#>
PREFIX orth: <http://purl.org/net/orth#>
PREFIX sio: <http://semanticscience.org/resource/>
PREFIX taxon: <http://purl.uniprot.org/taxonomy/>
PREFIX up: <http://purl.uniprot.org/core/>
PREFIX void: <http://rdfs.org/ns/void#>
PREFIX lscr: <http://purl.org/lscr#>
PREFIX genex: <http://purl.org/genex#>

select ?p ?taxon ?orthologGeneEns ?anat  where {

SERVICE <https://bgee.org/sparql/> {
	SELECT DISTINCT ?taxon {
        # ?taxon a up:Taxon .
    }
}

# ?p a orth:Protein.
# ?p orth:organism/obo:RO_0002162 taxon:559292.
# ?cluster a orth:OrthologsCluster.
# ?cluster orth:hasHomologousMember ?node1.
# ?cluster orth:hasHomologousMember ?node2. 
# ?node2 orth:hasHomologousMember* ?ortholog. 
# ?node1 orth:hasHomologousMember* ?p.
# ?ortholog sio:SIO_010079 ?gene . #is encoded by
# ?gene lscr:xrefEnsemblGene ?orthologGeneEns .
# ?ortholog orth:organism/obo:RO_0002162 ?taxon.
  
filter(?node1 != ?node2) 
  
SERVICE <https://bgee.org/sparql/> {
	SELECT DISTINCT ?orthologGeneEns ?anat {
		# ?geneB a orth:Gene .
		# ?geneB lscr:xrefEnsemblGene ?orthologGeneEns .
        # ?expr <http://purl.org/genex#hasSequenceUnit> ?geneB.
        # ?expr a <http://purl.org/genex#Expression> .
        # ?expr genex:hasConfidenceLevel obo:CIO_0000029 . # high confidence level
        # ?expr genex:hasExpressionLevel ?exprLevel .
        FILTER (?exprLevel > 99) # highly expressed
        # ?cond genex:hasAnatomicalEntity ?anat .
	}
}
 
}

"""

sparql_endpoint_OMA.setQuery(query_Bgee_OMA)
sparql_endpoint_OMA.setReturnFormat(JSON)

results = sparql_endpoint_OMA.query().convert()

pretty_print(results)
# Out:
# CPU times: user 8.14 s, sys: 2.4 s, total: 10.5 s
# Wall time: 52min 36s
#                                                   p  \
# 0        https://omabrowser.org/oma/info/YEAST03743
# 1        https://omabrowser.org/oma/info/YEAST03743
# 2        https://omabrowser.org/oma/info/YEAST03743
# 3        https://omabrowser.org/oma/info/YEAST03743
# 4        https://omabrowser.org/oma/info/YEAST03743
# ...                                             ...
# 1048571  https://omabrowser.org/oma/info/YEAST03625
# 1048572  https://omabrowser.org/oma/info/YEAST03625
# 1048573  https://omabrowser.org/oma/info/YEAST03625
# 1048574  https://omabrowser.org/oma/info/YEAST03625
# 1048575  https://omabrowser.org/oma/info/YEAST03625
#
#                                           taxon  \
# 0        http://purl.uniprot.org/taxonomy/10090
# 1        http://purl.uniprot.org/taxonomy/10090
# 2        http://purl.uniprot.org/taxonomy/10090
# 3        http://purl.uniprot.org/taxonomy/10090
# 4        http://purl.uniprot.org/taxonomy/10090
# ...                                         ...
# 1048571  http://purl.uniprot.org/taxonomy/9796
# 1048572  http://purl.uniprot.org/taxonomy/9796
# 1048573  http://purl.uniprot.org/taxonomy/9796
# 1048574  http://purl.uniprot.org/taxonomy/9796
# 1048575  http://purl.uniprot.org/taxonomy/9796
#
#                                                   orthologGeneEns  \
# 0        http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000026111
# 1        http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000026111
# 2        http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000026111
# 3        http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000026111
# 4        http://rdf.ebi.ac.uk/resource/ensembl/ENSMUSG00000026111
# ...                                                           ...
# 1048571  http://rdf.ebi.ac.uk/resource/ensembl/ENSECAG00000011097
# 1048572  http://rdf.ebi.ac.uk/resource/ensembl/ENSECAG00000011097
# 1048573  http://rdf.ebi.ac.uk/resource/ensembl/ENSECAG00000011097
# 1048574  http://rdf.ebi.ac.uk/resource/ensembl/ENSECAG00000011097
# 1048575  http://rdf.ebi.ac.uk/resource/ensembl/ENSECAG00000011097
#
#                                                   anat
# 0        http://purl.obolibrary.org/obo/UBERON_0001152
# 1        http://purl.obolibrary.org/obo/UBERON_0001174
# 2        http://purl.obolibrary.org/obo/UBERON_0002205
# 3        http://purl.obolibrary.org/obo/UBERON_0002395
# 4        http://purl.obolibrary.org/obo/UBERON_0003700
# ...                                                ...
# 1048571  http://purl.obolibrary.org/obo/CL_0000842
# 1048572  http://purl.obolibrary.org/obo/UBERON_0000051
# 1048573  http://purl.obolibrary.org/obo/UBERON_0000569
# 1048574  http://purl.obolibrary.org/obo/UBERON_0001371
# 1048575  http://purl.obolibrary.org/obo/UBERON_0001374
#
# [1048576 rows x 4 columns]

# %% [markdown]
# ### The size of the result is over 1M entries with execution time almost 1h!
# #### Lesson learned no. 2: some federated queries can take a very long time to complete (or timeout)

# %% [markdown]
# ### 5. Attempt aggregation via SPARQL: compute number of orthologs and average expression breadth per ortholog

# %%
....

# %% [markdown]
# ### 5b. Variant: compute aggregation directly in Python

# %%
pretty_print(results).head(100)
# Out:
#                                              p          species  \
# 0   https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 1   https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 2   https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 3   https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 4   https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# ..                                         ...              ...
# 95  https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 96  https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 97  https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 98  https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
# 99  https://omabrowser.org/oma/info/YEAST03651  Oryzias latipes
#
#                                              orthologGeneEns  \
# 0   http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 1   http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 2   http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 3   http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 4   http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# ..                                                       ...
# 95  http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 96  http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 97  http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 98  http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
# 99  http://rdf.ebi.ac.uk/resource/ensembl/ENSORLG00000018367
#
#                                              anat
# 0   http://purl.obolibrary.org/obo/UBERON_0001152
# 1   http://purl.obolibrary.org/obo/UBERON_0001174
# 2   http://purl.obolibrary.org/obo/UBERON_0002205
# 3   http://purl.obolibrary.org/obo/UBERON_0002395
# 4   http://purl.obolibrary.org/obo/UBERON_0003700
# ..                                            ...
# 95  http://purl.obolibrary.org/obo/UBERON_0005721
# 96  http://purl.obolibrary.org/obo/UBERON_0007005
# 97  http://purl.obolibrary.org/obo/UBERON_0007097
# 98  http://purl.obolibrary.org/obo/UBERON_0007098
# 99  http://purl.obolibrary.org/obo/UBERON_0007099
#
# [100 rows x 4 columns]

# %% [markdown]
# ### 6. Putting everything together: the query that should unite all information in this tutorial (note: will not run due to timeouts)

# %%
.....

# %% [markdown]
# ### Caveat: expression as hierarchy - are the same things counted twice? How do we take only the leaves? (use UBERON)
